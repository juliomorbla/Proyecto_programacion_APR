# %% [markdown]
# <a href="https://colab.research.google.com/github/juliomorbla/Proyecto_programacion_APR/blob/develop_bryan/Proyecto_pra%CC%81ctico_versionFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Julio Moreno Blanco
# *   Alumno 2: Mireia Carbó Feliu
# *   Alumno 3: Bryan Duque Gutiérrez

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/Proyecto_programacion_Final_APR"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: making sure  /content/gdrive/My Drive/08_MIAR/Proyecto_programacion_Final_APR  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/08_MIAR/Proyecto_programacion_Final_APR
# /content/gdrive/My Drive/08_MIAR/Proyecto_programacion_Final_APR
# Archivos en el directorio:
# ['POC2', 'POC4', 'model.png']

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
# Desinstalar versiones incompatibles preinstaladas en Colab
#!pip uninstall -y gym keras keras-nightly keras-Preprocessing keras-vis keras-applications tensorflow

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.12.0
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
  # %pip install tensorflow==2.12.0
  # %pip install protobuf==3.20

else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.11/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-7pneibb9
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-7pneibb9
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (1.23.5)
# Requirement already satisfied: pyglet==1.5.0 in /usr/local/lib/python3.11/dist-packages (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet==1.5.0) (1.0.0)
# Collecting h5py==3.1.0
#   Using cached h5py-3.1.0.tar.gz (371 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install backend dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing backend dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install backend dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: Pillow==9.5.0 in /usr/local/lib/python3.11/dist-packages (9.5.0)
# Requirement already satisfied: keras-rl2==1.0.5 in /usr/local/lib/python3.11/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow->keras-rl2==1.0.5)
#   Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.2.2)
# Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# orbax-checkpoint 0.11.15 requires jax>=0.5.0, but you have jax 0.4.30 which is incompatible.
# flax 0.10.6 requires jax>=0.5.1, but you have jax 0.4.30 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# bigframes 2.7.0 requires cloudpickle>=2.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# bigframes 2.7.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.12.0 which is incompatible.
# Successfully installed protobuf-4.25.8
# Collecting Keras==2.2.4
#   Using cached Keras-2.2.4-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (1.23.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (1.15.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (1.17.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (6.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (3.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from Keras==2.2.4) (1.1.2)
# Using cached Keras-2.2.4-py2.py3-none-any.whl (312 kB)
# Installing collected packages: Keras
#   Attempting uninstall: Keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires keras<2.13,>=2.12.0, but you have keras 2.2.4 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.12.0 which is incompatible.
# Successfully installed Keras-2.2.4
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.30)
# Collecting keras<2.13,>=2.12.0 (from tensorflow==2.12.0)
#   Using cached keras-2.12.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.2.4
#     Uninstalling Keras-2.2.4:
#       Successfully uninstalled Keras-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.12.0 which is incompatible.
# Successfully installed keras-2.12.0
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.11/dist-packages (2.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (18.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Requirement already satisfied: agents==1.4.0 in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from agents==1.4.0) (2.12.0)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (from agents==1.4.0) (0.17.3)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.11/dist-packages (from agents==1.4.0) (0.18.14)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym->agents==1.4.0) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym->agents==1.4.0) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym->agents==1.4.0) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym->agents==1.4.0) (1.6.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from ruamel.yaml->agents==1.4.0) (0.2.12)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->agents==1.4.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->agents==1.4.0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->agents==1.4.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->agents==1.4.0) (0.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->agents==1.4.0) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->agents==1.4.0) (3.2.2)
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)
# Collecting protobuf==3.20
#   Using cached protobuf-3.20.0-py2.py3-none-any.whl.metadata (720 bytes)
# Using cached protobuf-3.20.0-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
#     Uninstalling protobuf-4.25.8:
#       Successfully uninstalled protobuf-4.25.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-language 2.17.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-translate 3.20.3 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-iam 2.19.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-functions 1.20.4 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-aiplatform 1.97.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-firestore 2.21.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0dev,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-bigquery-storage 2.32.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-resource-manager 1.14.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.0 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.0 which is incompatible.
# google-api-core 2.25.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-spanner 3.55.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# grpc-google-iam-v1 0.14.2 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-bigquery-connection 1.18.3 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-datastore 2.21.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# orbax-checkpoint 0.11.15 requires jax>=0.5.0, but you have jax 0.4.30 which is incompatible.
# flax 0.10.6 requires jax>=0.5.1, but you have jax 0.4.30 which is incompatible.
# google-cloud-dataproc 5.20.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# googleapis-common-protos 1.70.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# bigframes 2.7.0 requires cloudpickle>=2.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# bigframes 2.7.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.12.0 which is incompatible.
# tensorflow-metadata 1.17.1 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.12.0 which is incompatible.
# Successfully installed protobuf-3.20.0

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# ### **Introducción**
#
# El entorno sobre el que vamos a trabajar es SpaceInvaders-v0, que pertenece a la colección de Atari Games disponible en Gymnasium. Es una versión del videojuego Space Invaders, donde controlasuna nave que se mueve lateralmente por la parte inferior de la pantalla y dispara a los enemigos que van bajando de la parte superior de la pantalla.
#
# El **objetivo principal** es sobrevivir y destruir enemigos, y se obtienen recomensas cuando se destruye al enemigo.
#
# Antes de implementar los modelos, debemos tener en cuenta diferentes cosas:
#
#
# *   Las observaciones son de tipo imagen RGB de 210x160 píxeles con 3 canales. Por lo tanto, nuestro **input** es de tipo imagen.
# *   Se pueden realizar diferentes tipos de **acciones**:
#     * 0: NOOP (no hacer nada)
#     * 1: FIRE (dispara)
#     * 2: RIGHT
#     * 3: LEFT
#     * 4: RIGHTFIRE
#     * 5: LEFTFIRE
# * **Recompensas**: Cada enemigo destruido da una recompensa positiva. Si pierdes una vida, no necesariamente recibes recompensa negativa, pero el episodio puede terminar.

# %% [markdown]
# #### Importar librerías

# %%
LEARNING_RATE = 0.0005

from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dense, Activation, Flatten, Convolution2D, Permute, Input,
                                     SeparableConv2D, Lambda, Subtract, Add, Conv2D,
                                     DepthwiseConv2D, BatchNormalization, ReLU, InputLayer)
from keras.optimizers import Adam
optimizer=Adam(learning_rate=LEARNING_RATE)
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy, GreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

import os
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import time
from tensorflow.keras.callbacks import Callback
from rl.callbacks import FileLogger


import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# %%
path = 'POC2'

# Define subdirectorios
videos_path = os.path.join(path, 'videos')
modelos_path = os.path.join(path, 'modelos')

# Crear directorios si no existen
os.makedirs(videos_path, exist_ok=True)
os.makedirs(modelos_path, exist_ok=True)

# %% [markdown]
# ### **Configuración base**

# %%
# Parámetros
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 1
GAMMA = 0.99
TARGET_MODEL_UPDATE = 1000
DELTA_CLIP = 1.0
TRAIN_INTERVAL = 4

# Entorno
env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
print("Numero de acciones disponibles: " + str(nb_actions))
# Out:
# Numero de acciones disponibles: 6

# %%
print("Formato de las observaciones:")
env.observation_space
# Out:
# Formato de las observaciones:
# Box(0, 255, (210, 160, 3), uint8)

# %% [markdown]
# Tal y como hemos visto, vamos a trabajar con las 6 acciones mencionadas anteriormente y con imágenes RGB de 210x160 píxeles y valores de intensidad de 0 a 255, lo cual es una entrada de alta dimensionalidad y con información que, en nuestro caso, puede ser rebundante o irrelevante para la toma de decisiones.
#
# Es por ello que creemos que puede ser mejor aplicar un preprocesamiento de la imagen, a una conversion de tonos grises, y reescalando la imagen.

# %%
# Obtener un estado inicial del entorno
obs = env.reset()
processor = AtariProcessor()

# Procesar la observación
processed_obs = processor.process_observation(obs)

# Mostrar imagen procesada
plt.imshow(processed_obs, cmap='gray')
plt.title("Observación procesada:")
plt.axis('off')
plt.show()

# %% [markdown]
# ## **1. Implementación de la red neuronal**

# %% [markdown]
# ### MODELO 4

# %%
def create_mobile_like_dqn(input_shape, num_actions):
    x_in = Input(shape=(input_shape[0], input_shape[1], input_shape[2]))
    x = Permute((2, 3, 1))(x_in)  # (84,84,frames)

    # Primer conv estándar ligero
    x = Conv2D(16, (3, 3), strides=2, padding='same')(x)  # ~(42x42x16)
    x = BatchNormalization()(x); x = ReLU()(x)

    # Bloque depthwise-pointwise
    def dw_pw(block_input, filters, strides):
        y = DepthwiseConv2D((3,3), strides=strides, padding='same')(block_input) # aplica una convolución 3x3 a cada canal por separado
        y = BatchNormalization()(y); y = ReLU()(y)
        y = Conv2D(filters, (1,1), padding='same')(y) # combina los canales resultantes, aprendiendo cómo mezclarlos (pointwise)
        y = BatchNormalization()(y); y = ReLU()(y)
        return y
    x = dw_pw(x, 32, strides=2)   # ~(21x21x32)
    x = dw_pw(x, 32, strides=2)   # ~(11x11x32)
    x = dw_pw(x, 64, strides=1)   # ~(11x11x64)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(num_actions, activation='linear', dtype='float32')(x)
    return Model(inputs=x_in, outputs=x)

# %%
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
num_actions = nb_actions

model_like_dqn = create_mobile_like_dqn(input_shape, num_actions)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/keras/layers/normalization/batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
plot_model(model_like_dqn,show_shapes=True, dpi=80)

# %% [markdown]
# ## **2. Implementación de la solución DQN**

# %%
# memoria
memory = SequentialMemory(limit=1_000_000, window_length=WINDOW_LENGTH)

# Procesador
processor = AtariProcessor()

# Polícia de exploración
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=1.0, value_min=0.05, value_test=0.01, nb_steps=200_000)

# %%
# Agente
dqn_like_dqn = DQNAgent(
    model=model_like_dqn,
    nb_actions=num_actions,
    policy=policy,
    memory=memory,
    processor=processor,
    nb_steps_warmup = 50000, # indica cuántos pasos (interacciones con el entorno) el agente debe ejecutar antes de comenzar a entrenar el modelo
    gamma=GAMMA,
    target_model_update = TARGET_MODEL_UPDATE,
    train_interval = TRAIN_INTERVAL,
    delta_clip = DELTA_CLIP
)

optimizer = Adam(learning_rate = LEARNING_RATE)

# %%
# Compilar el agente
dqn_like_dqn.compile(optimizer=optimizer, metrics=['mae'])

# %%
# Definimos un Callbak para poder guardar los mejores pesos cada 20 iteraciones
class SaveBestWeights(Callback):
    def __init__(self, filepath, interval=20, overwrite=True):
        super(SaveBestWeights, self).__init__()
        self.filepath = filepath
        self.interval = interval
        self.best_reward = -float('inf')
        self.overwrite = overwrite

    def on_episode_end(self, episode, logs={}):
        if episode % self.interval == 0:
            current_reward = logs.get('episode_reward')
            if current_reward > self.best_reward:
                self.best_reward = current_reward
                if self.overwrite or not os.path.exists(self.filepath):
                    self.model.save_weights(self.filepath, overwrite=True)
                    print(f'\n ##### Pesos guardados en {self.filepath} recompensa: {self.best_reward}')
                else:
                    print(f'\n ##### Warning: No se sobrescribió {self.filepath}, ya existe.')


# Definimos un Callbak para poder guardar los ultimos pesos cada 10 iteraciones, sin importar si mejoró el resultado del modelo
class SaveLastWeights(Callback):
    def __init__(self, filepath, interval=10):
        super(SaveLastWeights, self).__init__()
        self.filepath = filepath
        self.interval = interval

    def on_episode_end(self, episode, logs={}):
        if episode % self.interval == 0:
            self.model.save_weights(self.filepath, overwrite=True)
            print(f'\n ##### Pesos guardados en {self.filepath} al final del episodio {episode}')

# %%
path = 'POC4'

# Define subdirectorios
videos_path = os.path.join(path, 'videos')
modelos_path = os.path.join(path, 'modelos')

# Crear directorios si no existen
os.makedirs(videos_path, exist_ok=True)
os.makedirs(modelos_path, exist_ok=True)

log_filename = os.path.join(modelos_path, f'dqn_{env_name}_log.json')

filepath_bw = os.path.join(modelos_path, 'dqn_best_weights.h5')
save_best_weights = SaveBestWeights(filepath=filepath_bw, interval=50, overwrite=True)

filepath_lw = os.path.join(modelos_path, 'dqn_last_weights.h5')
save_last_weights = SaveLastWeights(filepath=filepath_lw, interval=50)

print("########--------------  modelo 4  ------------------###########")

start_time = time.time()

train_scores = dqn_like_dqn.fit(env, nb_steps=1_000_000, visualize=False, verbose=1, log_interval=5000,
                       callbacks=[save_best_weights, save_last_weights, FileLogger(log_filename, interval=100)])

end_time = time.time()
training_duration = end_time - start_time

print(f"Entrenamiento completado en {training_duration:.2f} segundos ({training_duration/60:.2f} minutos)")

weights_filename = os.path.join(modelos_path, 'dqn_last_weights.h5')
dqn_like_dqn.load_weights(weights_filename)
test_scores = dqn_like_dqn.test(env, nb_episodes=10, visualize=False)

episode_rewards = test_scores.history['episode_reward']
print(int(np.min(episode_rewards)), "~", int(np.max(episode_rewards)), "Mean", np.mean(episode_rewards))
# Out:
# ########--------------  modelo 4  ------------------###########
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#  544/5000 [==>...........................] - ETA: 19s - reward: 0.0110
#  ##### Pesos guardados en POC4/modelos/dqn_best_weights.h5 recompensa: 6.0
#
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 0
# 5000/5000 [==============================] - 23s 5ms/step - reward: 0.0124
# 7 episodes - episode_reward: 8.571 [4.000, 14.000] - ale.lives: 2.198
#
# Interval 2 (5000 steps performed)
# 5000/5000 [==============================] - 20s 4ms/step - reward: 0.0150
# 8 episodes - episode_reward: 9.500 [5.000, 13.000] - ale.lives: 2.060
#
# Interval 3 (10000 steps performed)
# 5000/5000 [==============================] - 20s 4ms/step - reward: 0.0144
# 8 episodes - episode_reward: 8.875 [6.000, 12.000] - ale.lives: 2.118
#
# Interval 4 (15000 steps performed)
# 5000/5000 [==============================] - 21s 4ms/step - reward: 0.0106
# 8 episodes - episode_reward: 6.875 [3.000, 8.000] - ale.lives: 2.137
#
# Interval 5 (20000 steps performed)
# 5000/5000 [==============================] - 20s 4ms/step - reward: 0.0158
# 8 episodes - episode_reward: 9.125 [6.000, 15.000] - ale.lives: 2.119
#
# Interval 6 (25000 steps performed)
# 5000/5000 [==============================] - 20s 4ms/step - reward: 0.0164
# 7 episodes - episode_reward: 10.143 [3.000, 20.000] - ale.lives: 2.202
#
# Interval 7 (30000 steps performed)
# 3535/5000 [====================>.........] - ETA: 6s - reward: 0.0167
#  ##### Pesos guardados en POC4/modelos/dqn_best_weights.h5 recompensa: 10.0
#
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 50
# 5000/5000 [==============================] - 22s 4ms/step - reward: 0.0178
# 6 episodes - episode_reward: 14.500 [8.000, 27.000] - ale.lives: 1.993
#
# Interval 8 (35000 steps performed)
# 5000/5000 [==============================] - 21s 4ms/step - reward: 0.0168
# 7 episodes - episode_reward: 14.000 [6.000, 24.000] - ale.lives: 2.117
#
# Interval 9 (40000 steps performed)
# 5000/5000 [==============================] - 21s 4ms/step - reward: 0.0130
# 6 episodes - episode_reward: 10.333 [4.000, 14.000] - ale.lives: 2.032
#
# Interval 10 (45000 steps performed)
# 5000/5000 [==============================] - 21s 4ms/step - reward: 0.0154
# 6 episodes - episode_reward: 12.500 [8.000, 22.000] - ale.lives: 2.016
#
# Interval 11 (50000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0130
# 6 episodes - episode_reward: 11.833 [4.000, 16.000] - loss: 0.019 - mae: 0.051 - mean_q: 0.073 - mean_eps: 0.751 - ale.lives: 1.900
#
# Interval 12 (55000 steps performed)
# 5000/5000 [==============================] - 78s 16ms/step - reward: 0.0148
# 8 episodes - episode_reward: 9.375 [4.000, 21.000] - loss: 0.007 - mae: 0.080 - mean_q: 0.097 - mean_eps: 0.727 - ale.lives: 2.185
#
# Interval 13 (60000 steps performed)
# 5000/5000 [==============================] - 78s 16ms/step - reward: 0.0170
# 7 episodes - episode_reward: 11.857 [8.000, 21.000] - loss: 0.007 - mae: 0.144 - mean_q: 0.172 - mean_eps: 0.703 - ale.lives: 2.010
#
# Interval 14 (65000 steps performed)
# 5000/5000 [==============================] - 78s 16ms/step - reward: 0.0132
# 7 episodes - episode_reward: 9.286 [4.000, 18.000] - loss: 0.007 - mae: 0.206 - mean_q: 0.247 - mean_eps: 0.679 - ale.lives: 1.947
#
# Interval 15 (70000 steps performed)
#  837/5000 [====>.........................] - ETA: 1:05 - reward: 0.0167
#  ##### Pesos guardados en POC4/modelos/dqn_best_weights.h5 recompensa: 13.0
#
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 100
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0132
# 6 episodes - episode_reward: 10.500 [5.000, 17.000] - loss: 0.007 - mae: 0.270 - mean_q: 0.325 - mean_eps: 0.656 - ale.lives: 2.137
#
# Interval 16 (75000 steps performed)
# 5000/5000 [==============================] - 78s 16ms/step - reward: 0.0158
# 7 episodes - episode_reward: 12.286 [9.000, 19.000] - loss: 0.008 - mae: 0.334 - mean_q: 0.400 - mean_eps: 0.632 - ale.lives: 1.890
#
# Interval 17 (80000 steps performed)
# 5000/5000 [==============================] - 79s 16ms/step - reward: 0.0174
# 9 episodes - episode_reward: 9.889 [2.000, 21.000] - loss: 0.007 - mae: 0.386 - mean_q: 0.463 - mean_eps: 0.608 - ale.lives: 2.102
#
# Interval 18 (85000 steps performed)
# 5000/5000 [==============================] - 79s 16ms/step - reward: 0.0176
# 7 episodes - episode_reward: 11.571 [4.000, 20.000] - loss: 0.008 - mae: 0.447 - mean_q: 0.537 - mean_eps: 0.584 - ale.lives: 1.964
#
# Interval 19 (90000 steps performed)
# 5000/5000 [==============================] - 80s 16ms/step - reward: 0.0126
# 9 episodes - episode_reward: 7.444 [4.000, 17.000] - loss: 0.007 - mae: 0.499 - mean_q: 0.599 - mean_eps: 0.561 - ale.lives: 2.009
#
# Interval 20 (95000 steps performed)
# 5000/5000 [==============================] - 80s 16ms/step - reward: 0.0134
# 6 episodes - episode_reward: 10.833 [8.000, 16.000] - loss: 0.008 - mae: 0.543 - mean_q: 0.651 - mean_eps: 0.537 - ale.lives: 1.871
#
# Interval 21 (100000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0152
# 5 episodes - episode_reward: 15.400 [8.000, 26.000] - loss: 0.007 - mae: 0.586 - mean_q: 0.702 - mean_eps: 0.513 - ale.lives: 1.852
#
# Interval 22 (105000 steps performed)
# 2325/5000 [============>.................] - ETA: 43s - reward: 0.0155
#  ##### Pesos guardados en POC4/modelos/dqn_best_weights.h5 recompensa: 25.0
#
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 150
# 5000/5000 [==============================] - 83s 17ms/step - reward: 0.0182
# 5 episodes - episode_reward: 19.000 [5.000, 29.000] - loss: 0.008 - mae: 0.624 - mean_q: 0.748 - mean_eps: 0.489 - ale.lives: 2.023
#
# Interval 23 (110000 steps performed)
# 5000/5000 [==============================] - 80s 16ms/step - reward: 0.0142
# 6 episodes - episode_reward: 10.500 [5.000, 16.000] - loss: 0.008 - mae: 0.664 - mean_q: 0.796 - mean_eps: 0.466 - ale.lives: 1.941
#
# Interval 24 (115000 steps performed)
# 5000/5000 [==============================] - 80s 16ms/step - reward: 0.0164
# 7 episodes - episode_reward: 12.857 [5.000, 25.000] - loss: 0.008 - mae: 0.703 - mean_q: 0.843 - mean_eps: 0.442 - ale.lives: 1.767
#
# Interval 25 (120000 steps performed)
# 5000/5000 [==============================] - 80s 16ms/step - reward: 0.0166
# 6 episodes - episode_reward: 13.333 [5.000, 28.000] - loss: 0.008 - mae: 0.741 - mean_q: 0.888 - mean_eps: 0.418 - ale.lives: 2.160
#
# Interval 26 (125000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0180
# 6 episodes - episode_reward: 14.167 [9.000, 23.000] - loss: 0.008 - mae: 0.778 - mean_q: 0.933 - mean_eps: 0.394 - ale.lives: 2.024
#
# Interval 27 (130000 steps performed)
# 5000/5000 [==============================] - 80s 16ms/step - reward: 0.0136
# 5 episodes - episode_reward: 13.200 [8.000, 18.000] - loss: 0.008 - mae: 0.810 - mean_q: 0.972 - mean_eps: 0.371 - ale.lives: 2.249
#
# Interval 28 (135000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0168
# 7 episodes - episode_reward: 12.143 [3.000, 19.000] - loss: 0.008 - mae: 0.840 - mean_q: 1.008 - mean_eps: 0.347 - ale.lives: 1.937
#
# Interval 29 (140000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0158
# 5 episodes - episode_reward: 15.000 [7.000, 28.000] - loss: 0.008 - mae: 0.878 - mean_q: 1.054 - mean_eps: 0.323 - ale.lives: 1.875
#
# Interval 30 (145000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0130
# 5 episodes - episode_reward: 12.400 [4.000, 19.000] - loss: 0.008 - mae: 0.913 - mean_q: 1.094 - mean_eps: 0.299 - ale.lives: 2.018
#
# Interval 31 (150000 steps performed)
#   69/5000 [..............................] - ETA: 1:18 - reward: 0.0000e+00
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 200
# 5000/5000 [==============================] - 82s 16ms/step - reward: 0.0126
# 7 episodes - episode_reward: 10.429 [6.000, 16.000] - loss: 0.008 - mae: 0.939 - mean_q: 1.127 - mean_eps: 0.276 - ale.lives: 2.115
#
# Interval 32 (155000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0140
# 5 episodes - episode_reward: 15.200 [8.000, 25.000] - loss: 0.008 - mae: 0.971 - mean_q: 1.166 - mean_eps: 0.252 - ale.lives: 1.868
#
# Interval 33 (160000 steps performed)
# 5000/5000 [==============================] - 81s 16ms/step - reward: 0.0114
# 6 episodes - episode_reward: 9.000 [5.000, 17.000] - loss: 0.008 - mae: 1.001 - mean_q: 1.200 - mean_eps: 0.228 - ale.lives: 1.892
#
# Interval 34 (165000 steps performed)
# 5000/5000 [==============================] - 82s 16ms/step - reward: 0.0166
# 7 episodes - episode_reward: 12.286 [3.000, 19.000] - loss: 0.009 - mae: 1.026 - mean_q: 1.230 - mean_eps: 0.204 - ale.lives: 1.905
#
# Interval 35 (170000 steps performed)
# 5000/5000 [==============================] - 82s 16ms/step - reward: 0.0136
# 5 episodes - episode_reward: 12.800 [8.000, 15.000] - loss: 0.008 - mae: 1.048 - mean_q: 1.257 - mean_eps: 0.181 - ale.lives: 2.168
#
# Interval 36 (175000 steps performed)
# 5000/5000 [==============================] - 82s 16ms/step - reward: 0.0144
# 5 episodes - episode_reward: 13.000 [6.000, 18.000] - loss: 0.008 - mae: 1.066 - mean_q: 1.278 - mean_eps: 0.157 - ale.lives: 2.186
#
# Interval 37 (180000 steps performed)
# 5000/5000 [==============================] - 83s 17ms/step - reward: 0.0130
# 6 episodes - episode_reward: 11.833 [7.000, 18.000] - loss: 0.008 - mae: 1.088 - mean_q: 1.305 - mean_eps: 0.133 - ale.lives: 1.853
#
# Interval 38 (185000 steps performed)
# 5000/5000 [==============================] - 83s 17ms/step - reward: 0.0118
# 5 episodes - episode_reward: 11.600 [5.000, 17.000] - loss: 0.008 - mae: 1.104 - mean_q: 1.324 - mean_eps: 0.109 - ale.lives: 1.935
#
# Interval 39 (190000 steps performed)
# 4561/5000 [==========================>...] - ETA: 7s - reward: 0.0127
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 250
# 5000/5000 [==============================] - 85s 17ms/step - reward: 0.0128
# 5 episodes - episode_reward: 12.800 [8.000, 19.000] - loss: 0.008 - mae: 1.120 - mean_q: 1.344 - mean_eps: 0.086 - ale.lives: 2.073
#
# Interval 40 (195000 steps performed)
# 5000/5000 [==============================] - 83s 17ms/step - reward: 0.0124
# 5 episodes - episode_reward: 13.200 [4.000, 19.000] - loss: 0.008 - mae: 1.138 - mean_q: 1.365 - mean_eps: 0.062 - ale.lives: 1.773
#
# Interval 41 (200000 steps performed)
# 5000/5000 [==============================] - 83s 17ms/step - reward: 0.0128
# 7 episodes - episode_reward: 8.714 [1.000, 19.000] - loss: 0.008 - mae: 1.151 - mean_q: 1.381 - mean_eps: 0.050 - ale.lives: 2.032
#
# Interval 42 (205000 steps performed)
# 5000/5000 [==============================] - 83s 17ms/step - reward: 0.0160
# 5 episodes - episode_reward: 17.000 [9.000, 24.000] - loss: 0.009 - mae: 1.171 - mean_q: 1.405 - mean_eps: 0.050 - ale.lives: 1.803
#
# Interval 43 (210000 steps performed)
# 5000/5000 [==============================] - 84s 17ms/step - reward: 0.0190
# 6 episodes - episode_reward: 15.000 [6.000, 20.000] - loss: 0.009 - mae: 1.187 - mean_q: 1.424 - mean_eps: 0.050 - ale.lives: 1.949
#
# Interval 44 (215000 steps performed)
# 5000/5000 [==============================] - 84s 17ms/step - reward: 0.0150
# 5 episodes - episode_reward: 13.600 [9.000, 19.000] - loss: 0.009 - mae: 1.205 - mean_q: 1.445 - mean_eps: 0.050 - ale.lives: 1.943
#
# Interval 45 (220000 steps performed)
# 5000/5000 [==============================] - 84s 17ms/step - reward: 0.0134
# 4 episodes - episode_reward: 16.750 [7.000, 27.000] - loss: 0.009 - mae: 1.224 - mean_q: 1.469 - mean_eps: 0.050 - ale.lives: 2.108
#
# Interval 46 (225000 steps performed)
# 5000/5000 [==============================] - 85s 17ms/step - reward: 0.0164
# 5 episodes - episode_reward: 17.800 [14.000, 23.000] - loss: 0.008 - mae: 1.240 - mean_q: 1.488 - mean_eps: 0.050 - ale.lives: 1.986
#
# Interval 47 (230000 steps performed)
# 5000/5000 [==============================] - 85s 17ms/step - reward: 0.0120
# 4 episodes - episode_reward: 13.250 [11.000, 17.000] - loss: 0.008 - mae: 1.252 - mean_q: 1.502 - mean_eps: 0.050 - ale.lives: 1.956
#
# Interval 48 (235000 steps performed)
# 5000/5000 [==============================] - 85s 17ms/step - reward: 0.0154
# 6 episodes - episode_reward: 13.333 [9.000, 16.000] - loss: 0.008 - mae: 1.261 - mean_q: 1.513 - mean_eps: 0.050 - ale.lives: 2.007
#
# Interval 49 (240000 steps performed)
# 2185/5000 [============>.................] - ETA: 48s - reward: 0.0114
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 300
# 5000/5000 [==============================] - 87s 17ms/step - reward: 0.0138
# 6 episodes - episode_reward: 11.500 [4.000, 18.000] - loss: 0.008 - mae: 1.271 - mean_q: 1.524 - mean_eps: 0.050 - ale.lives: 2.057
#
# Interval 50 (245000 steps performed)
# 5000/5000 [==============================] - 85s 17ms/step - reward: 0.0154
# 5 episodes - episode_reward: 14.800 [12.000, 18.000] - loss: 0.009 - mae: 1.279 - mean_q: 1.533 - mean_eps: 0.050 - ale.lives: 2.055
#
# Interval 51 (250000 steps performed)
# 5000/5000 [==============================] - 86s 17ms/step - reward: 0.0144
# 6 episodes - episode_reward: 13.000 [9.000, 16.000] - loss: 0.009 - mae: 1.293 - mean_q: 1.550 - mean_eps: 0.050 - ale.lives: 1.970
#
# Interval 52 (255000 steps performed)
# 5000/5000 [==============================] - 86s 17ms/step - reward: 0.0134
# 7 episodes - episode_reward: 10.429 [3.000, 16.000] - loss: 0.010 - mae: 1.307 - mean_q: 1.567 - mean_eps: 0.050 - ale.lives: 1.896
#
# Interval 53 (260000 steps performed)
# 5000/5000 [==============================] - 86s 17ms/step - reward: 0.0162
# 5 episodes - episode_reward: 11.400 [4.000, 17.000] - loss: 0.008 - mae: 1.312 - mean_q: 1.573 - mean_eps: 0.050 - ale.lives: 1.972
#
# Interval 54 (265000 steps performed)
# 5000/5000 [==============================] - 87s 17ms/step - reward: 0.0126
# 5 episodes - episode_reward: 16.400 [6.000, 31.000] - loss: 0.009 - mae: 1.314 - mean_q: 1.576 - mean_eps: 0.050 - ale.lives: 2.047
#
# Interval 55 (270000 steps performed)
# 5000/5000 [==============================] - 87s 17ms/step - reward: 0.0182
# 5 episodes - episode_reward: 17.200 [13.000, 23.000] - loss: 0.008 - mae: 1.324 - mean_q: 1.589 - mean_eps: 0.050 - ale.lives: 1.917
#
# Interval 56 (275000 steps performed)
# 5000/5000 [==============================] - 87s 17ms/step - reward: 0.0158
# 6 episodes - episode_reward: 13.500 [11.000, 16.000] - loss: 0.008 - mae: 1.330 - mean_q: 1.596 - mean_eps: 0.050 - ale.lives: 1.859
#
# Interval 57 (280000 steps performed)
# 5000/5000 [==============================] - 88s 18ms/step - reward: 0.0170
# 6 episodes - episode_reward: 13.500 [8.000, 21.000] - loss: 0.010 - mae: 1.341 - mean_q: 1.609 - mean_eps: 0.050 - ale.lives: 2.105
#
# Interval 58 (285000 steps performed)
# 1145/5000 [=====>........................] - ETA: 1:07 - reward: 0.0114
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 350
# 5000/5000 [==============================] - 89s 18ms/step - reward: 0.0134
# 6 episodes - episode_reward: 13.000 [7.000, 19.000] - loss: 0.008 - mae: 1.353 - mean_q: 1.624 - mean_eps: 0.050 - ale.lives: 2.005
#
# Interval 59 (290000 steps performed)
# 5000/5000 [==============================] - 88s 18ms/step - reward: 0.0126
# 5 episodes - episode_reward: 12.000 [7.000, 16.000] - loss: 0.009 - mae: 1.360 - mean_q: 1.631 - mean_eps: 0.050 - ale.lives: 1.981
#
# Interval 60 (295000 steps performed)
# 5000/5000 [==============================] - 88s 18ms/step - reward: 0.0182
# 6 episodes - episode_reward: 15.833 [4.000, 30.000] - loss: 0.008 - mae: 1.367 - mean_q: 1.640 - mean_eps: 0.050 - ale.lives: 2.188
#
# Interval 61 (300000 steps performed)
# 5000/5000 [==============================] - 89s 18ms/step - reward: 0.0166
# 5 episodes - episode_reward: 14.200 [12.000, 17.000] - loss: 0.009 - mae: 1.379 - mean_q: 1.655 - mean_eps: 0.050 - ale.lives: 1.973
#
# Interval 62 (305000 steps performed)
# 5000/5000 [==============================] - 89s 18ms/step - reward: 0.0168
# 6 episodes - episode_reward: 14.167 [11.000, 18.000] - loss: 0.009 - mae: 1.395 - mean_q: 1.673 - mean_eps: 0.050 - ale.lives: 1.974
#
# Interval 63 (310000 steps performed)
# 5000/5000 [==============================] - 89s 18ms/step - reward: 0.0172
# 6 episodes - episode_reward: 14.667 [7.000, 17.000] - loss: 0.008 - mae: 1.403 - mean_q: 1.685 - mean_eps: 0.050 - ale.lives: 2.037
#
# Interval 64 (315000 steps performed)
# 5000/5000 [==============================] - 90s 18ms/step - reward: 0.0170
# 6 episodes - episode_reward: 15.667 [12.000, 19.000] - loss: 0.009 - mae: 1.410 - mean_q: 1.692 - mean_eps: 0.050 - ale.lives: 1.808
#
# Interval 65 (320000 steps performed)
# 5000/5000 [==============================] - 89s 18ms/step - reward: 0.0204
# 6 episodes - episode_reward: 15.167 [5.000, 22.000] - loss: 0.009 - mae: 1.414 - mean_q: 1.697 - mean_eps: 0.050 - ale.lives: 2.067
#
# Interval 66 (325000 steps performed)
# 5000/5000 [==============================] - 89s 18ms/step - reward: 0.0174
# 5 episodes - episode_reward: 17.000 [14.000, 20.000] - loss: 0.009 - mae: 1.426 - mean_q: 1.712 - mean_eps: 0.050 - ale.lives: 1.945
#
# Interval 67 (330000 steps performed)
#  561/5000 [==>...........................] - ETA: 1:19 - reward: 0.0160
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 400
# 5000/5000 [==============================] - 91s 18ms/step - reward: 0.0156
# 5 episodes - episode_reward: 16.800 [10.000, 22.000] - loss: 0.009 - mae: 1.440 - mean_q: 1.728 - mean_eps: 0.050 - ale.lives: 1.894
#
# Interval 68 (335000 steps performed)
# 5000/5000 [==============================] - 90s 18ms/step - reward: 0.0138
# 6 episodes - episode_reward: 12.167 [8.000, 15.000] - loss: 0.009 - mae: 1.444 - mean_q: 1.732 - mean_eps: 0.050 - ale.lives: 2.040
#
# Interval 69 (340000 steps performed)
# 5000/5000 [==============================] - 91s 18ms/step - reward: 0.0122
# 4 episodes - episode_reward: 14.500 [7.000, 25.000] - loss: 0.009 - mae: 1.445 - mean_q: 1.735 - mean_eps: 0.050 - ale.lives: 1.733
#
# Interval 70 (345000 steps performed)
# 5000/5000 [==============================] - 92s 18ms/step - reward: 0.0148
# 5 episodes - episode_reward: 14.000 [10.000, 17.000] - loss: 0.009 - mae: 1.451 - mean_q: 1.743 - mean_eps: 0.050 - ale.lives: 2.199
#
# Interval 71 (350000 steps performed)
# 5000/5000 [==============================] - 92s 18ms/step - reward: 0.0172
# 5 episodes - episode_reward: 17.400 [10.000, 26.000] - loss: 0.009 - mae: 1.459 - mean_q: 1.751 - mean_eps: 0.050 - ale.lives: 1.879
#
# Interval 72 (355000 steps performed)
# 5000/5000 [==============================] - 91s 18ms/step - reward: 0.0164
# 5 episodes - episode_reward: 18.200 [12.000, 31.000] - loss: 0.009 - mae: 1.463 - mean_q: 1.756 - mean_eps: 0.050 - ale.lives: 1.948
#
# Interval 73 (360000 steps performed)
# 5000/5000 [==============================] - 92s 18ms/step - reward: 0.0172
# 4 episodes - episode_reward: 18.750 [16.000, 23.000] - loss: 0.009 - mae: 1.472 - mean_q: 1.768 - mean_eps: 0.050 - ale.lives: 1.806
#
# Interval 74 (365000 steps performed)
# 5000/5000 [==============================] - 94s 19ms/step - reward: 0.0182
# 6 episodes - episode_reward: 14.833 [10.000, 19.000] - loss: 0.009 - mae: 1.489 - mean_q: 1.788 - mean_eps: 0.050 - ale.lives: 1.973
#
# Interval 75 (370000 steps performed)
# 5000/5000 [==============================] - 92s 18ms/step - reward: 0.0162
# 5 episodes - episode_reward: 16.600 [7.000, 26.000] - loss: 0.009 - mae: 1.502 - mean_q: 1.802 - mean_eps: 0.050 - ale.lives: 1.929
#
# Interval 76 (375000 steps performed)
# 4941/5000 [============================>.] - ETA: 1s - reward: 0.0174
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 450
# 5000/5000 [==============================] - 94s 19ms/step - reward: 0.0172
# 6 episodes - episode_reward: 16.167 [6.000, 30.000] - loss: 0.008 - mae: 1.503 - mean_q: 1.802 - mean_eps: 0.050 - ale.lives: 1.836
#
# Interval 77 (380000 steps performed)
# 5000/5000 [==============================] - 93s 19ms/step - reward: 0.0176
# 4 episodes - episode_reward: 20.500 [11.000, 28.000] - loss: 0.009 - mae: 1.496 - mean_q: 1.794 - mean_eps: 0.050 - ale.lives: 1.874
#
# Interval 78 (385000 steps performed)
# 5000/5000 [==============================] - 93s 19ms/step - reward: 0.0160
# 6 episodes - episode_reward: 12.833 [5.000, 19.000] - loss: 0.009 - mae: 1.496 - mean_q: 1.794 - mean_eps: 0.050 - ale.lives: 2.047
#
# Interval 79 (390000 steps performed)
# 5000/5000 [==============================] - 93s 19ms/step - reward: 0.0172
# 7 episodes - episode_reward: 12.429 [6.000, 21.000] - loss: 0.008 - mae: 1.501 - mean_q: 1.801 - mean_eps: 0.050 - ale.lives: 2.048
#
# Interval 80 (395000 steps performed)
# 5000/5000 [==============================] - 94s 19ms/step - reward: 0.0164
# 6 episodes - episode_reward: 13.500 [10.000, 18.000] - loss: 0.009 - mae: 1.507 - mean_q: 1.811 - mean_eps: 0.050 - ale.lives: 2.031
#
# Interval 81 (400000 steps performed)
# 5000/5000 [==============================] - 94s 19ms/step - reward: 0.0164
# 6 episodes - episode_reward: 14.167 [7.000, 20.000] - loss: 0.009 - mae: 1.516 - mean_q: 1.820 - mean_eps: 0.050 - ale.lives: 2.129
#
# Interval 82 (405000 steps performed)
# 5000/5000 [==============================] - 95s 19ms/step - reward: 0.0200
# 7 episodes - episode_reward: 14.143 [6.000, 25.000] - loss: 0.008 - mae: 1.521 - mean_q: 1.825 - mean_eps: 0.050 - ale.lives: 2.237
#
# Interval 83 (410000 steps performed)
# 5000/5000 [==============================] - 95s 19ms/step - reward: 0.0186
# 4 episodes - episode_reward: 18.000 [12.000, 21.000] - loss: 0.009 - mae: 1.519 - mean_q: 1.823 - mean_eps: 0.050 - ale.lives: 1.743
#
# Interval 84 (415000 steps performed)
# 5000/5000 [==============================] - 95s 19ms/step - reward: 0.0128
# 6 episodes - episode_reward: 15.333 [5.000, 28.000] - loss: 0.009 - mae: 1.519 - mean_q: 1.821 - mean_eps: 0.050 - ale.lives: 2.093
#
# Interval 85 (420000 steps performed)
# 3309/5000 [==================>...........] - ETA: 32s - reward: 0.0209
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 500
# 5000/5000 [==============================] - 97s 19ms/step - reward: 0.0186
# 5 episodes - episode_reward: 17.000 [12.000, 21.000] - loss: 0.009 - mae: 1.524 - mean_q: 1.829 - mean_eps: 0.050 - ale.lives: 1.877
#
# Interval 86 (425000 steps performed)
# 5000/5000 [==============================] - 96s 19ms/step - reward: 0.0168
# 6 episodes - episode_reward: 14.167 [10.000, 17.000] - loss: 0.009 - mae: 1.533 - mean_q: 1.842 - mean_eps: 0.050 - ale.lives: 1.955
#
# Interval 87 (430000 steps performed)
# 5000/5000 [==============================] - 96s 19ms/step - reward: 0.0178
# 6 episodes - episode_reward: 14.667 [9.000, 20.000] - loss: 0.010 - mae: 1.538 - mean_q: 1.845 - mean_eps: 0.050 - ale.lives: 1.877
#
# Interval 88 (435000 steps performed)
# 5000/5000 [==============================] - 96s 19ms/step - reward: 0.0180
# 5 episodes - episode_reward: 17.000 [14.000, 18.000] - loss: 0.009 - mae: 1.536 - mean_q: 1.845 - mean_eps: 0.050 - ale.lives: 1.843
#
# Interval 89 (440000 steps performed)
# 5000/5000 [==============================] - 96s 19ms/step - reward: 0.0158
# 7 episodes - episode_reward: 12.143 [2.000, 22.000] - loss: 0.009 - mae: 1.542 - mean_q: 1.850 - mean_eps: 0.050 - ale.lives: 1.978
#
# Interval 90 (445000 steps performed)
# 5000/5000 [==============================] - 96s 19ms/step - reward: 0.0148
# 4 episodes - episode_reward: 18.000 [14.000, 21.000] - loss: 0.009 - mae: 1.542 - mean_q: 1.852 - mean_eps: 0.050 - ale.lives: 2.046
#
# Interval 91 (450000 steps performed)
# 5000/5000 [==============================] - 96s 19ms/step - reward: 0.0182
# 6 episodes - episode_reward: 15.333 [9.000, 21.000] - loss: 0.009 - mae: 1.540 - mean_q: 1.848 - mean_eps: 0.050 - ale.lives: 1.924
#
# Interval 92 (455000 steps performed)
# 5000/5000 [==============================] - 97s 19ms/step - reward: 0.0104
# 5 episodes - episode_reward: 11.400 [5.000, 16.000] - loss: 0.009 - mae: 1.544 - mean_q: 1.853 - mean_eps: 0.050 - ale.lives: 1.977
#
# Interval 93 (460000 steps performed)
# 5000/5000 [==============================] - 97s 19ms/step - reward: 0.0126
# 6 episodes - episode_reward: 10.667 [5.000, 18.000] - loss: 0.009 - mae: 1.550 - mean_q: 1.860 - mean_eps: 0.050 - ale.lives: 1.994
#
# Interval 94 (465000 steps performed)
# 2769/5000 [===============>..............] - ETA: 43s - reward: 0.0188
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 550
# 5000/5000 [==============================] - 99s 20ms/step - reward: 0.0180
# 6 episodes - episode_reward: 13.167 [7.000, 20.000] - loss: 0.010 - mae: 1.556 - mean_q: 1.867 - mean_eps: 0.050 - ale.lives: 2.006
#
# Interval 95 (470000 steps performed)
# 5000/5000 [==============================] - 97s 19ms/step - reward: 0.0174
# 4 episodes - episode_reward: 20.250 [15.000, 25.000] - loss: 0.009 - mae: 1.555 - mean_q: 1.865 - mean_eps: 0.050 - ale.lives: 1.741
#
# Interval 96 (475000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0162
# 5 episodes - episode_reward: 18.600 [12.000, 23.000] - loss: 0.010 - mae: 1.554 - mean_q: 1.865 - mean_eps: 0.050 - ale.lives: 1.873
#
# Interval 97 (480000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0160
# 6 episodes - episode_reward: 14.500 [7.000, 20.000] - loss: 0.009 - mae: 1.552 - mean_q: 1.861 - mean_eps: 0.050 - ale.lives: 2.158
#
# Interval 98 (485000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0200
# 6 episodes - episode_reward: 16.500 [12.000, 25.000] - loss: 0.009 - mae: 1.552 - mean_q: 1.863 - mean_eps: 0.050 - ale.lives: 1.852
#
# Interval 99 (490000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0190
# 5 episodes - episode_reward: 18.000 [12.000, 22.000] - loss: 0.009 - mae: 1.554 - mean_q: 1.865 - mean_eps: 0.050 - ale.lives: 1.898
#
# Interval 100 (495000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0170
# 5 episodes - episode_reward: 16.600 [11.000, 20.000] - loss: 0.008 - mae: 1.554 - mean_q: 1.865 - mean_eps: 0.050 - ale.lives: 1.872
#
# Interval 101 (500000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0130
# 4 episodes - episode_reward: 15.500 [13.000, 17.000] - loss: 0.009 - mae: 1.555 - mean_q: 1.867 - mean_eps: 0.050 - ale.lives: 1.750
#
# Interval 102 (505000 steps performed)
# 5000/5000 [==============================] - 98s 20ms/step - reward: 0.0176
# 6 episodes - episode_reward: 15.167 [9.000, 22.000] - loss: 0.010 - mae: 1.559 - mean_q: 1.871 - mean_eps: 0.050 - ale.lives: 1.965
#
# Interval 103 (510000 steps performed)
# 5000/5000 [==============================] - 99s 20ms/step - reward: 0.0150
# 4 episodes - episode_reward: 20.500 [19.000, 22.000] - loss: 0.009 - mae: 1.562 - mean_q: 1.874 - mean_eps: 0.050 - ale.lives: 2.112
#
# Interval 104 (515000 steps performed)
# 4009/5000 [=======================>......] - ETA: 19s - reward: 0.0137
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 600
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0152
# 4 episodes - episode_reward: 19.250 [14.000, 26.000] - loss: 0.009 - mae: 1.560 - mean_q: 1.873 - mean_eps: 0.050 - ale.lives: 1.695
#
# Interval 105 (520000 steps performed)
# 5000/5000 [==============================] - 100s 20ms/step - reward: 0.0114
# 4 episodes - episode_reward: 10.750 [5.000, 14.000] - loss: 0.009 - mae: 1.556 - mean_q: 1.867 - mean_eps: 0.050 - ale.lives: 1.833
#
# Interval 106 (525000 steps performed)
# 5000/5000 [==============================] - 100s 20ms/step - reward: 0.0172
# 5 episodes - episode_reward: 18.800 [13.000, 28.000] - loss: 0.009 - mae: 1.548 - mean_q: 1.857 - mean_eps: 0.050 - ale.lives: 1.754
#
# Interval 107 (530000 steps performed)
# 5000/5000 [==============================] - 100s 20ms/step - reward: 0.0164
# 5 episodes - episode_reward: 15.600 [11.000, 19.000] - loss: 0.009 - mae: 1.547 - mean_q: 1.857 - mean_eps: 0.050 - ale.lives: 1.824
#
# Interval 108 (535000 steps performed)
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0164
# 5 episodes - episode_reward: 15.400 [11.000, 19.000] - loss: 0.009 - mae: 1.546 - mean_q: 1.856 - mean_eps: 0.050 - ale.lives: 1.778
#
# Interval 109 (540000 steps performed)
# 5000/5000 [==============================] - 100s 20ms/step - reward: 0.0214
# 6 episodes - episode_reward: 18.000 [6.000, 27.000] - loss: 0.009 - mae: 1.550 - mean_q: 1.861 - mean_eps: 0.050 - ale.lives: 1.971
#
# Interval 110 (545000 steps performed)
# 5000/5000 [==============================] - 100s 20ms/step - reward: 0.0170
# 5 episodes - episode_reward: 18.200 [16.000, 22.000] - loss: 0.009 - mae: 1.550 - mean_q: 1.861 - mean_eps: 0.050 - ale.lives: 2.001
#
# Interval 111 (550000 steps performed)
# 5000/5000 [==============================] - 100s 20ms/step - reward: 0.0176
# 5 episodes - episode_reward: 18.000 [12.000, 28.000] - loss: 0.009 - mae: 1.550 - mean_q: 1.861 - mean_eps: 0.050 - ale.lives: 1.941
#
# Interval 112 (555000 steps performed)
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0176
# 5 episodes - episode_reward: 15.000 [8.000, 23.000] - loss: 0.009 - mae: 1.548 - mean_q: 1.857 - mean_eps: 0.050 - ale.lives: 1.889
#
# Interval 113 (560000 steps performed)
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0214
# 8 episodes - episode_reward: 15.000 [11.000, 19.000] - loss: 0.009 - mae: 1.540 - mean_q: 1.849 - mean_eps: 0.050 - ale.lives: 2.081
#
# Interval 114 (565000 steps performed)
#  693/5000 [===>..........................] - ETA: 1:26 - reward: 0.0202
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 650
# 5000/5000 [==============================] - 102s 20ms/step - reward: 0.0212
# 6 episodes - episode_reward: 16.167 [13.000, 20.000] - loss: 0.009 - mae: 1.543 - mean_q: 1.851 - mean_eps: 0.050 - ale.lives: 2.062
#
# Interval 115 (570000 steps performed)
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0218
# 7 episodes - episode_reward: 17.714 [15.000, 20.000] - loss: 0.009 - mae: 1.544 - mean_q: 1.854 - mean_eps: 0.050 - ale.lives: 1.900
#
# Interval 116 (575000 steps performed)
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0174
# 4 episodes - episode_reward: 20.750 [15.000, 25.000] - loss: 0.009 - mae: 1.547 - mean_q: 1.857 - mean_eps: 0.050 - ale.lives: 2.186
#
# Interval 117 (580000 steps performed)
# 5000/5000 [==============================] - 101s 20ms/step - reward: 0.0216
# 6 episodes - episode_reward: 15.500 [12.000, 22.000] - loss: 0.010 - mae: 1.551 - mean_q: 1.862 - mean_eps: 0.050 - ale.lives: 1.980
#
# Interval 118 (585000 steps performed)
# 5000/5000 [==============================] - 102s 20ms/step - reward: 0.0206
# 7 episodes - episode_reward: 16.714 [14.000, 20.000] - loss: 0.009 - mae: 1.550 - mean_q: 1.861 - mean_eps: 0.050 - ale.lives: 2.050
#
# Interval 119 (590000 steps performed)
# 5000/5000 [==============================] - 102s 20ms/step - reward: 0.0180
# 5 episodes - episode_reward: 16.600 [14.000, 21.000] - loss: 0.009 - mae: 1.554 - mean_q: 1.866 - mean_eps: 0.050 - ale.lives: 1.938
#
# Interval 120 (595000 steps performed)
# 5000/5000 [==============================] - 102s 20ms/step - reward: 0.0202
# 6 episodes - episode_reward: 16.333 [12.000, 20.000] - loss: 0.010 - mae: 1.563 - mean_q: 1.878 - mean_eps: 0.050 - ale.lives: 2.074
#
# Interval 121 (600000 steps performed)
# 5000/5000 [==============================] - 103s 21ms/step - reward: 0.0158
# 4 episodes - episode_reward: 19.750 [15.000, 24.000] - loss: 0.009 - mae: 1.567 - mean_q: 1.881 - mean_eps: 0.050 - ale.lives: 2.029
#
# Interval 122 (605000 steps performed)
# 4789/5000 [===========================>..] - ETA: 4s - reward: 0.0211
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 700
# 5000/5000 [==============================] - 105s 21ms/step - reward: 0.0216
# 6 episodes - episode_reward: 19.333 [17.000, 21.000] - loss: 0.010 - mae: 1.569 - mean_q: 1.884 - mean_eps: 0.050 - ale.lives: 2.087
#
# Interval 123 (610000 steps performed)
# 5000/5000 [==============================] - 103s 21ms/step - reward: 0.0240
# 7 episodes - episode_reward: 16.000 [14.000, 18.000] - loss: 0.009 - mae: 1.576 - mean_q: 1.892 - mean_eps: 0.050 - ale.lives: 2.134
#
# Interval 124 (615000 steps performed)
# 5000/5000 [==============================] - 103s 21ms/step - reward: 0.0174
# 6 episodes - episode_reward: 14.833 [12.000, 17.000] - loss: 0.010 - mae: 1.579 - mean_q: 1.895 - mean_eps: 0.050 - ale.lives: 2.024
#
# Interval 125 (620000 steps performed)
# 5000/5000 [==============================] - 104s 21ms/step - reward: 0.0184
# 8 episodes - episode_reward: 12.125 [5.000, 19.000] - loss: 0.009 - mae: 1.579 - mean_q: 1.896 - mean_eps: 0.050 - ale.lives: 1.989
#
# Interval 126 (625000 steps performed)
# 5000/5000 [==============================] - 104s 21ms/step - reward: 0.0160
# 5 episodes - episode_reward: 14.200 [12.000, 17.000] - loss: 0.009 - mae: 1.581 - mean_q: 1.898 - mean_eps: 0.050 - ale.lives: 1.887
#
# Interval 127 (630000 steps performed)
# 5000/5000 [==============================] - 104s 21ms/step - reward: 0.0200
# 6 episodes - episode_reward: 17.333 [14.000, 19.000] - loss: 0.009 - mae: 1.584 - mean_q: 1.901 - mean_eps: 0.050 - ale.lives: 1.901
#
# Interval 128 (635000 steps performed)
# 5000/5000 [==============================] - 105s 21ms/step - reward: 0.0206
# 6 episodes - episode_reward: 17.500 [13.000, 25.000] - loss: 0.010 - mae: 1.591 - mean_q: 1.912 - mean_eps: 0.050 - ale.lives: 2.003
#
# Interval 129 (640000 steps performed)
# 5000/5000 [==============================] - 105s 21ms/step - reward: 0.0164
# 5 episodes - episode_reward: 15.400 [10.000, 19.000] - loss: 0.009 - mae: 1.597 - mean_q: 1.916 - mean_eps: 0.050 - ale.lives: 1.870
#
# Interval 130 (645000 steps performed)
# 4801/5000 [===========================>..] - ETA: 4s - reward: 0.0212
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 750
# 5000/5000 [==============================] - 107s 21ms/step - reward: 0.0212
# 7 episodes - episode_reward: 16.857 [11.000, 24.000] - loss: 0.009 - mae: 1.595 - mean_q: 1.913 - mean_eps: 0.050 - ale.lives: 1.979
#
# Interval 131 (650000 steps performed)
# 5000/5000 [==============================] - 105s 21ms/step - reward: 0.0118
# 4 episodes - episode_reward: 13.750 [10.000, 16.000] - loss: 0.009 - mae: 1.590 - mean_q: 1.908 - mean_eps: 0.050 - ale.lives: 1.975
#
# Interval 132 (655000 steps performed)
# 5000/5000 [==============================] - 107s 21ms/step - reward: 0.0168
# 5 episodes - episode_reward: 15.400 [7.000, 25.000] - loss: 0.010 - mae: 1.585 - mean_q: 1.903 - mean_eps: 0.050 - ale.lives: 2.092
#
# Interval 133 (660000 steps performed)
# 5000/5000 [==============================] - 106s 21ms/step - reward: 0.0196
# 6 episodes - episode_reward: 18.167 [12.000, 30.000] - loss: 0.009 - mae: 1.590 - mean_q: 1.908 - mean_eps: 0.050 - ale.lives: 1.969
#
# Interval 134 (665000 steps performed)
# 5000/5000 [==============================] - 107s 21ms/step - reward: 0.0144
# 5 episodes - episode_reward: 14.000 [8.000, 19.000] - loss: 0.010 - mae: 1.591 - mean_q: 1.908 - mean_eps: 0.050 - ale.lives: 1.844
#
# Interval 135 (670000 steps performed)
# 5000/5000 [==============================] - 107s 21ms/step - reward: 0.0198
# 5 episodes - episode_reward: 17.000 [15.000, 19.000] - loss: 0.009 - mae: 1.595 - mean_q: 1.915 - mean_eps: 0.050 - ale.lives: 2.283
#
# Interval 136 (675000 steps performed)
# 5000/5000 [==============================] - 107s 21ms/step - reward: 0.0136
# 3 episodes - episode_reward: 24.000 [11.000, 33.000] - loss: 0.010 - mae: 1.595 - mean_q: 1.914 - mean_eps: 0.050 - ale.lives: 2.049
#
# Interval 137 (680000 steps performed)
# 5000/5000 [==============================] - 107s 21ms/step - reward: 0.0176
# 6 episodes - episode_reward: 16.833 [14.000, 21.000] - loss: 0.009 - mae: 1.595 - mean_q: 1.914 - mean_eps: 0.050 - ale.lives: 1.749
#
# Interval 138 (685000 steps performed)
# 5000/5000 [==============================] - 108s 22ms/step - reward: 0.0176
# 6 episodes - episode_reward: 15.000 [11.000, 21.000] - loss: 0.010 - mae: 1.603 - mean_q: 1.924 - mean_eps: 0.050 - ale.lives: 2.009
#
# Interval 139 (690000 steps performed)
# 5000/5000 [==============================] - 108s 22ms/step - reward: 0.0180
# 4 episodes - episode_reward: 18.750 [15.000, 22.000] - loss: 0.010 - mae: 1.609 - mean_q: 1.932 - mean_eps: 0.050 - ale.lives: 2.117
#
# Interval 140 (695000 steps performed)
# 4969/5000 [============================>.] - ETA: 0s - reward: 0.0177
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 800
# 5000/5000 [==============================] - 110s 22ms/step - reward: 0.0176
# 6 episodes - episode_reward: 17.333 [13.000, 23.000] - loss: 0.009 - mae: 1.610 - mean_q: 1.934 - mean_eps: 0.050 - ale.lives: 2.097
#
# Interval 141 (700000 steps performed)
# 5000/5000 [==============================] - 109s 22ms/step - reward: 0.0190
# 4 episodes - episode_reward: 21.000 [17.000, 24.000] - loss: 0.010 - mae: 1.617 - mean_q: 1.942 - mean_eps: 0.050 - ale.lives: 1.779
#
# Interval 142 (705000 steps performed)
# 5000/5000 [==============================] - 110s 22ms/step - reward: 0.0190
# 6 episodes - episode_reward: 16.333 [13.000, 20.000] - loss: 0.010 - mae: 1.617 - mean_q: 1.941 - mean_eps: 0.050 - ale.lives: 1.897
#
# Interval 143 (710000 steps performed)
# 5000/5000 [==============================] - 110s 22ms/step - reward: 0.0212
# 6 episodes - episode_reward: 17.500 [12.000, 21.000] - loss: 0.010 - mae: 1.618 - mean_q: 1.944 - mean_eps: 0.050 - ale.lives: 2.029
#
# Interval 144 (715000 steps performed)
# 5000/5000 [==============================] - 111s 22ms/step - reward: 0.0184
# 5 episodes - episode_reward: 16.800 [12.000, 27.000] - loss: 0.010 - mae: 1.616 - mean_q: 1.941 - mean_eps: 0.050 - ale.lives: 1.983
#
# Interval 145 (720000 steps performed)
# 5000/5000 [==============================] - 111s 22ms/step - reward: 0.0194
# 7 episodes - episode_reward: 15.857 [4.000, 20.000] - loss: 0.010 - mae: 1.613 - mean_q: 1.936 - mean_eps: 0.050 - ale.lives: 2.076
#
# Interval 146 (725000 steps performed)
# 5000/5000 [==============================] - 111s 22ms/step - reward: 0.0192
# 6 episodes - episode_reward: 15.833 [12.000, 21.000] - loss: 0.009 - mae: 1.614 - mean_q: 1.937 - mean_eps: 0.050 - ale.lives: 2.027
#
# Interval 147 (730000 steps performed)
# 5000/5000 [==============================] - 111s 22ms/step - reward: 0.0154
# 5 episodes - episode_reward: 14.600 [11.000, 22.000] - loss: 0.009 - mae: 1.612 - mean_q: 1.935 - mean_eps: 0.050 - ale.lives: 1.949
#
# Interval 148 (735000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0158
# 6 episodes - episode_reward: 14.500 [6.000, 22.000] - loss: 0.010 - mae: 1.617 - mean_q: 1.942 - mean_eps: 0.050 - ale.lives: 1.870
#
# Interval 149 (740000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0146
# 4 episodes - episode_reward: 15.250 [9.000, 23.000] - loss: 0.010 - mae: 1.624 - mean_q: 1.949 - mean_eps: 0.050 - ale.lives: 2.019
#
# Interval 150 (745000 steps performed)
#  425/5000 [=>............................] - ETA: 1:42 - reward: 0.0094
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 850
# 5000/5000 [==============================] - 114s 23ms/step - reward: 0.0178
# 5 episodes - episode_reward: 18.400 [8.000, 28.000] - loss: 0.009 - mae: 1.621 - mean_q: 1.947 - mean_eps: 0.050 - ale.lives: 1.920
#
# Interval 151 (750000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0174
# 5 episodes - episode_reward: 18.200 [10.000, 26.000] - loss: 0.009 - mae: 1.620 - mean_q: 1.945 - mean_eps: 0.050 - ale.lives: 2.214
#
# Interval 152 (755000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0202
# 7 episodes - episode_reward: 14.714 [6.000, 19.000] - loss: 0.010 - mae: 1.615 - mean_q: 1.940 - mean_eps: 0.050 - ale.lives: 1.942
#
# Interval 153 (760000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0152
# 4 episodes - episode_reward: 19.750 [15.000, 30.000] - loss: 0.010 - mae: 1.621 - mean_q: 1.944 - mean_eps: 0.050 - ale.lives: 2.232
#
# Interval 154 (765000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0172
# 5 episodes - episode_reward: 14.200 [8.000, 22.000] - loss: 0.010 - mae: 1.616 - mean_q: 1.939 - mean_eps: 0.050 - ale.lives: 1.920
#
# Interval 155 (770000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0146
# 6 episodes - episode_reward: 14.667 [11.000, 17.000] - loss: 0.010 - mae: 1.622 - mean_q: 1.948 - mean_eps: 0.050 - ale.lives: 1.959
#
# Interval 156 (775000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0182
# 6 episodes - episode_reward: 15.167 [12.000, 18.000] - loss: 0.011 - mae: 1.625 - mean_q: 1.952 - mean_eps: 0.050 - ale.lives: 1.865
#
# Interval 157 (780000 steps performed)
# 5000/5000 [==============================] - 112s 22ms/step - reward: 0.0212
# 6 episodes - episode_reward: 16.667 [13.000, 22.000] - loss: 0.009 - mae: 1.624 - mean_q: 1.949 - mean_eps: 0.050 - ale.lives: 2.114
#
# Interval 158 (785000 steps performed)
# 5000/5000 [==============================] - 115s 23ms/step - reward: 0.0176
# 6 episodes - episode_reward: 15.167 [8.000, 19.000] - loss: 0.010 - mae: 1.619 - mean_q: 1.943 - mean_eps: 0.050 - ale.lives: 2.049
#
# Interval 159 (790000 steps performed)
#  521/5000 [==>...........................] - ETA: 1:42 - reward: 0.0250
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 900
# 5000/5000 [==============================] - 116s 23ms/step - reward: 0.0186
# 6 episodes - episode_reward: 14.833 [13.000, 20.000] - loss: 0.010 - mae: 1.615 - mean_q: 1.937 - mean_eps: 0.050 - ale.lives: 1.921
#
# Interval 160 (795000 steps performed)
# 5000/5000 [==============================] - 114s 23ms/step - reward: 0.0182
# 5 episodes - episode_reward: 18.400 [15.000, 21.000] - loss: 0.010 - mae: 1.625 - mean_q: 1.950 - mean_eps: 0.050 - ale.lives: 1.928
#
# Interval 161 (800000 steps performed)
# 5000/5000 [==============================] - 114s 23ms/step - reward: 0.0172
# 6 episodes - episode_reward: 13.000 [8.000, 18.000] - loss: 0.010 - mae: 1.627 - mean_q: 1.952 - mean_eps: 0.050 - ale.lives: 1.911
#
# Interval 162 (805000 steps performed)
# 5000/5000 [==============================] - 114s 23ms/step - reward: 0.0186
# 5 episodes - episode_reward: 19.600 [16.000, 22.000] - loss: 0.009 - mae: 1.629 - mean_q: 1.956 - mean_eps: 0.050 - ale.lives: 1.670
#
# Interval 163 (810000 steps performed)
# 5000/5000 [==============================] - 115s 23ms/step - reward: 0.0196
# 7 episodes - episode_reward: 14.143 [9.000, 17.000] - loss: 0.010 - mae: 1.627 - mean_q: 1.953 - mean_eps: 0.050 - ale.lives: 2.009
#
# Interval 164 (815000 steps performed)
# 5000/5000 [==============================] - 115s 23ms/step - reward: 0.0164
# 6 episodes - episode_reward: 13.000 [7.000, 18.000] - loss: 0.010 - mae: 1.626 - mean_q: 1.952 - mean_eps: 0.050 - ale.lives: 2.037
#
# Interval 165 (820000 steps performed)
# 5000/5000 [==============================] - 116s 23ms/step - reward: 0.0210
# 6 episodes - episode_reward: 17.000 [11.000, 22.000] - loss: 0.010 - mae: 1.626 - mean_q: 1.952 - mean_eps: 0.050 - ale.lives: 2.046
#
# Interval 166 (825000 steps performed)
# 5000/5000 [==============================] - 116s 23ms/step - reward: 0.0190
# 6 episodes - episode_reward: 17.000 [11.000, 21.000] - loss: 0.009 - mae: 1.624 - mean_q: 1.950 - mean_eps: 0.050 - ale.lives: 2.024
#
# Interval 167 (830000 steps performed)
# 2541/5000 [==============>...............] - ETA: 56s - reward: 0.0161
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 950
# 5000/5000 [==============================] - 118s 24ms/step - reward: 0.0206
# 7 episodes - episode_reward: 15.000 [4.000, 24.000] - loss: 0.010 - mae: 1.628 - mean_q: 1.955 - mean_eps: 0.050 - ale.lives: 2.016
#
# Interval 168 (835000 steps performed)
# 5000/5000 [==============================] - 116s 23ms/step - reward: 0.0198
# 6 episodes - episode_reward: 15.833 [8.000, 20.000] - loss: 0.009 - mae: 1.636 - mean_q: 1.965 - mean_eps: 0.050 - ale.lives: 2.113
#
# Interval 169 (840000 steps performed)
# 5000/5000 [==============================] - 117s 23ms/step - reward: 0.0150
# 5 episodes - episode_reward: 14.800 [11.000, 18.000] - loss: 0.010 - mae: 1.636 - mean_q: 1.964 - mean_eps: 0.050 - ale.lives: 1.914
#
# Interval 170 (845000 steps performed)
# 5000/5000 [==============================] - 117s 23ms/step - reward: 0.0184
# 5 episodes - episode_reward: 18.600 [13.000, 24.000] - loss: 0.010 - mae: 1.634 - mean_q: 1.962 - mean_eps: 0.050 - ale.lives: 1.966
#
# Interval 171 (850000 steps performed)
# 5000/5000 [==============================] - 117s 23ms/step - reward: 0.0168
# 6 episodes - episode_reward: 14.000 [6.000, 22.000] - loss: 0.010 - mae: 1.636 - mean_q: 1.964 - mean_eps: 0.050 - ale.lives: 2.179
#
# Interval 172 (855000 steps performed)
# 5000/5000 [==============================] - 117s 23ms/step - reward: 0.0176
# 5 episodes - episode_reward: 15.400 [12.000, 19.000] - loss: 0.009 - mae: 1.632 - mean_q: 1.958 - mean_eps: 0.050 - ale.lives: 1.818
#
# Interval 173 (860000 steps performed)
# 5000/5000 [==============================] - 118s 24ms/step - reward: 0.0164
# 4 episodes - episode_reward: 21.750 [16.000, 26.000] - loss: 0.010 - mae: 1.624 - mean_q: 1.952 - mean_eps: 0.050 - ale.lives: 1.581
#
# Interval 174 (865000 steps performed)
# 5000/5000 [==============================] - 118s 24ms/step - reward: 0.0172
# 5 episodes - episode_reward: 18.800 [13.000, 29.000] - loss: 0.010 - mae: 1.628 - mean_q: 1.956 - mean_eps: 0.050 - ale.lives: 1.969
#
# Interval 175 (870000 steps performed)
# 5000/5000 [==============================] - 117s 23ms/step - reward: 0.0134
# 4 episodes - episode_reward: 16.750 [16.000, 19.000] - loss: 0.010 - mae: 1.630 - mean_q: 1.956 - mean_eps: 0.050 - ale.lives: 1.749
#
# Interval 176 (875000 steps performed)
# 5000/5000 [==============================] - 118s 24ms/step - reward: 0.0136
# 5 episodes - episode_reward: 12.400 [6.000, 18.000] - loss: 0.010 - mae: 1.631 - mean_q: 1.958 - mean_eps: 0.050 - ale.lives: 2.056
#
# Interval 177 (880000 steps performed)
# 1117/5000 [=====>........................] - ETA: 1:32 - reward: 0.0206
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 1000
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0208
# 6 episodes - episode_reward: 16.833 [12.000, 23.000] - loss: 0.010 - mae: 1.638 - mean_q: 1.967 - mean_eps: 0.050 - ale.lives: 2.116
#
# Interval 178 (885000 steps performed)
# 5000/5000 [==============================] - 118s 24ms/step - reward: 0.0164
# 6 episodes - episode_reward: 16.167 [9.000, 33.000] - loss: 0.010 - mae: 1.643 - mean_q: 1.973 - mean_eps: 0.050 - ale.lives: 1.716
#
# Interval 179 (890000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0136
# 3 episodes - episode_reward: 13.000 [3.000, 25.000] - loss: 0.009 - mae: 1.645 - mean_q: 1.972 - mean_eps: 0.050 - ale.lives: 2.492
#
# Interval 180 (895000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0192
# 4 episodes - episode_reward: 29.000 [15.000, 51.000] - loss: 0.009 - mae: 1.639 - mean_q: 1.968 - mean_eps: 0.050 - ale.lives: 1.790
#
# Interval 181 (900000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0182
# 5 episodes - episode_reward: 17.800 [15.000, 21.000] - loss: 0.010 - mae: 1.645 - mean_q: 1.976 - mean_eps: 0.050 - ale.lives: 1.821
#
# Interval 182 (905000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0202
# 5 episodes - episode_reward: 20.200 [14.000, 28.000] - loss: 0.010 - mae: 1.647 - mean_q: 1.976 - mean_eps: 0.050 - ale.lives: 1.856
#
# Interval 183 (910000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0162
# 4 episodes - episode_reward: 17.000 [11.000, 24.000] - loss: 0.010 - mae: 1.651 - mean_q: 1.981 - mean_eps: 0.050 - ale.lives: 2.143
#
# Interval 184 (915000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0206
# 7 episodes - episode_reward: 18.429 [14.000, 31.000] - loss: 0.009 - mae: 1.648 - mean_q: 1.979 - mean_eps: 0.050 - ale.lives: 2.111
#
# Interval 185 (920000 steps performed)
# 5000/5000 [==============================] - 119s 24ms/step - reward: 0.0198
# 6 episodes - episode_reward: 16.167 [11.000, 18.000] - loss: 0.010 - mae: 1.646 - mean_q: 1.975 - mean_eps: 0.050 - ale.lives: 1.903
#
# Interval 186 (925000 steps performed)
# 4221/5000 [========================>.....] - ETA: 18s - reward: 0.0180
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 1050
# 5000/5000 [==============================] - 122s 24ms/step - reward: 0.0168
# 6 episodes - episode_reward: 13.000 [4.000, 26.000] - loss: 0.011 - mae: 1.641 - mean_q: 1.969 - mean_eps: 0.050 - ale.lives: 1.883
#
# Interval 187 (930000 steps performed)
# 5000/5000 [==============================] - 120s 24ms/step - reward: 0.0168
# 5 episodes - episode_reward: 16.200 [14.000, 20.000] - loss: 0.010 - mae: 1.645 - mean_q: 1.974 - mean_eps: 0.050 - ale.lives: 1.839
#
# Interval 188 (935000 steps performed)
# 5000/5000 [==============================] - 120s 24ms/step - reward: 0.0164
# 6 episodes - episode_reward: 15.333 [11.000, 23.000] - loss: 0.009 - mae: 1.644 - mean_q: 1.975 - mean_eps: 0.050 - ale.lives: 1.925
#
# Interval 189 (940000 steps performed)
# 5000/5000 [==============================] - 121s 24ms/step - reward: 0.0136
# 5 episodes - episode_reward: 11.600 [2.000, 20.000] - loss: 0.011 - mae: 1.646 - mean_q: 1.977 - mean_eps: 0.050 - ale.lives: 1.987
#
# Interval 190 (945000 steps performed)
# 5000/5000 [==============================] - 121s 24ms/step - reward: 0.0162
# 5 episodes - episode_reward: 16.000 [13.000, 21.000] - loss: 0.010 - mae: 1.648 - mean_q: 1.979 - mean_eps: 0.050 - ale.lives: 1.966
#
# Interval 191 (950000 steps performed)
# 5000/5000 [==============================] - 121s 24ms/step - reward: 0.0156
# 5 episodes - episode_reward: 15.800 [12.000, 24.000] - loss: 0.009 - mae: 1.643 - mean_q: 1.972 - mean_eps: 0.050 - ale.lives: 2.069
#
# Interval 192 (955000 steps performed)
# 5000/5000 [==============================] - 121s 24ms/step - reward: 0.0174
# 4 episodes - episode_reward: 23.000 [20.000, 31.000] - loss: 0.010 - mae: 1.637 - mean_q: 1.965 - mean_eps: 0.050 - ale.lives: 1.860
#
# Interval 193 (960000 steps performed)
# 5000/5000 [==============================] - 122s 24ms/step - reward: 0.0154
# 5 episodes - episode_reward: 15.400 [12.000, 21.000] - loss: 0.010 - mae: 1.638 - mean_q: 1.966 - mean_eps: 0.050 - ale.lives: 1.761
#
# Interval 194 (965000 steps performed)
# 5000/5000 [==============================] - 122s 24ms/step - reward: 0.0204
# 6 episodes - episode_reward: 16.333 [10.000, 20.000] - loss: 0.010 - mae: 1.636 - mean_q: 1.963 - mean_eps: 0.050 - ale.lives: 1.907
#
# Interval 195 (970000 steps performed)
# 5000/5000 [==============================] - 122s 24ms/step - reward: 0.0186
# 5 episodes - episode_reward: 19.000 [5.000, 33.000] - loss: 0.010 - mae: 1.631 - mean_q: 1.958 - mean_eps: 0.050 - ale.lives: 2.079
#
# Interval 196 (975000 steps performed)
# 3441/5000 [===================>..........] - ETA: 38s - reward: 0.0171
#  ##### Pesos guardados en POC4/modelos/dqn_last_weights.h5 al final del episodio 1100
# 5000/5000 [==============================] - 124s 25ms/step - reward: 0.0198
# 6 episodes - episode_reward: 15.333 [9.000, 22.000] - loss: 0.010 - mae: 1.630 - mean_q: 1.956 - mean_eps: 0.050 - ale.lives: 2.027
#
# Interval 197 (980000 steps performed)
# 5000/5000 [==============================] - 122s 24ms/step - reward: 0.0194
# 6 episodes - episode_reward: 17.000 [12.000, 20.000] - loss: 0.010 - mae: 1.624 - mean_q: 1.950 - mean_eps: 0.050 - ale.lives: 1.996
#
# Interval 198 (985000 steps performed)
# 5000/5000 [==============================] - 123s 25ms/step - reward: 0.0168
# 5 episodes - episode_reward: 17.600 [15.000, 22.000] - loss: 0.010 - mae: 1.627 - mean_q: 1.954 - mean_eps: 0.050 - ale.lives: 1.926
#
# Interval 199 (990000 steps performed)
# 5000/5000 [==============================] - 124s 25ms/step - reward: 0.0200
# 6 episodes - episode_reward: 16.333 [12.000, 27.000] - loss: 0.010 - mae: 1.631 - mean_q: 1.958 - mean_eps: 0.050 - ale.lives: 1.817
#
# Interval 200 (995000 steps performed)
# 5000/5000 [==============================] - 124s 25ms/step - reward: 0.0204
# done, took 19247.574 seconds
# Entrenamiento completado en 19247.58 segundos (320.79 minutos)
# Testing for 10 episodes ...
# Episode 1: reward: 18.000, steps: 721
# Episode 2: reward: 18.000, steps: 721
# Episode 3: reward: 18.000, steps: 714
# Episode 4: reward: 18.000, steps: 716
# Episode 5: reward: 18.000, steps: 721
# Episode 6: reward: 18.000, steps: 713
# Episode 7: reward: 18.000, steps: 711
# Episode 8: reward: 18.000, steps: 725
# Episode 9: reward: 18.000, steps: 723
# Episode 10: reward: 18.000, steps: 717
# 18 ~ 18 Mean 18.0

# %%
filepath_bw = os.path.join(modelos_path, 'dqn_best_weights.h5')
save_best_weights = SaveBestWeights(filepath=filepath_bw, interval=50, overwrite=True)

filepath_lw = os.path.join(modelos_path, 'dqn_last_weights.h5')
save_last_weights = SaveLastWeights(filepath=filepath_lw, interval=50)

# %%
import h5py

with h5py.File(filepath_bw, 'r') as f:
    print("Estructura del archivo:")
    f.visit(print)
# Out:
# Estructura del archivo:
# batch_normalization
# batch_normalization/batch_normalization
# batch_normalization/batch_normalization/beta:0
# batch_normalization/batch_normalization/gamma:0
# batch_normalization/batch_normalization/moving_mean:0
# batch_normalization/batch_normalization/moving_variance:0
# batch_normalization_1
# batch_normalization_1/batch_normalization_1
# batch_normalization_1/batch_normalization_1/beta:0
# batch_normalization_1/batch_normalization_1/gamma:0
# batch_normalization_1/batch_normalization_1/moving_mean:0
# batch_normalization_1/batch_normalization_1/moving_variance:0
# batch_normalization_2
# batch_normalization_2/batch_normalization_2
# batch_normalization_2/batch_normalization_2/beta:0
# batch_normalization_2/batch_normalization_2/gamma:0
# batch_normalization_2/batch_normalization_2/moving_mean:0
# batch_normalization_2/batch_normalization_2/moving_variance:0
# batch_normalization_3
# batch_normalization_3/batch_normalization_3
# batch_normalization_3/batch_normalization_3/beta:0
# batch_normalization_3/batch_normalization_3/gamma:0
# batch_normalization_3/batch_normalization_3/moving_mean:0
# batch_normalization_3/batch_normalization_3/moving_variance:0
# batch_normalization_4
# batch_normalization_4/batch_normalization_4
# batch_normalization_4/batch_normalization_4/beta:0
# batch_normalization_4/batch_normalization_4/gamma:0
# batch_normalization_4/batch_normalization_4/moving_mean:0
# batch_normalization_4/batch_normalization_4/moving_variance:0
# batch_normalization_5
# batch_normalization_5/batch_normalization_5
# batch_normalization_5/batch_normalization_5/beta:0
# batch_normalization_5/batch_normalization_5/gamma:0
# batch_normalization_5/batch_normalization_5/moving_mean:0
# batch_normalization_5/batch_normalization_5/moving_variance:0
# batch_normalization_6
# batch_normalization_6/batch_normalization_6
# batch_normalization_6/batch_normalization_6/beta:0
# batch_normalization_6/batch_normalization_6/gamma:0
# batch_normalization_6/batch_normalization_6/moving_mean:0
# batch_normalization_6/batch_normalization_6/moving_variance:0
# conv2d
# conv2d/conv2d
# conv2d/conv2d/bias:0
# conv2d/conv2d/kernel:0
# conv2d_1
# conv2d_1/conv2d_1
# conv2d_1/conv2d_1/bias:0
# conv2d_1/conv2d_1/kernel:0
# conv2d_2
# conv2d_2/conv2d_2
# conv2d_2/conv2d_2/bias:0
# conv2d_2/conv2d_2/kernel:0
# conv2d_3
# conv2d_3/conv2d_3
# conv2d_3/conv2d_3/bias:0
# conv2d_3/conv2d_3/kernel:0
# dense
# dense/dense
# dense/dense/bias:0
# dense/dense/kernel:0
# dense_1
# dense_1/dense_1
# dense_1/dense_1/bias:0
# dense_1/dense_1/kernel:0
# depthwise_conv2d
# depthwise_conv2d/depthwise_conv2d
# depthwise_conv2d/depthwise_conv2d/bias:0
# depthwise_conv2d/depthwise_conv2d/depthwise_kernel:0
# depthwise_conv2d_1
# depthwise_conv2d_1/depthwise_conv2d_1
# depthwise_conv2d_1/depthwise_conv2d_1/bias:0
# depthwise_conv2d_1/depthwise_conv2d_1/depthwise_kernel:0
# depthwise_conv2d_2
# depthwise_conv2d_2/depthwise_conv2d_2
# depthwise_conv2d_2/depthwise_conv2d_2/bias:0
# depthwise_conv2d_2/depthwise_conv2d_2/depthwise_kernel:0
# flatten
# input_1
# permute
# re_lu
# re_lu_1
# re_lu_2
# re_lu_3
# re_lu_4
# re_lu_5
# re_lu_6
# top_level_model_weights

# %% [markdown]
# ## **3. Justificación de los parámetros seleccionados y de los resultados obtenidos**

# %% [markdown]
# ---
